# %%
from classification import TStatFeatureSelector, BollingerBandDriftDetector, FixedSizeBuffer, BaseModelStockPredictor
from DataLoader import DataLoader
import pandas as pd
from itertools import product
from river import tree

# %% [markdown]
# ### DATA LOADING

# %%
stock_data = pd.read_csv("AAPL_full.csv")
ticker = 'AAPL'

# %%
ticker = 'AAPL'
dataLoader = DataLoader() # if yahoo does not work use "dataLoader.get_data_locally('AAPL')"
stock_data = dataLoader.pipeline(ticker)

# %%
stock_data
# Out:
#              open       close        high         low    volume       max_5  \
# 0        0.064731    0.064731    0.065159    0.064731  34272000    0.065588
# 1        0.064731    0.064731    0.065159    0.064731  37408000    0.065588
# 2        0.064731    0.064302    0.065159    0.064302  76092800    0.065588
# 3        0.063016    0.062159    0.063016    0.062159  25244800    0.064731
# 4        0.063873    0.063873    0.064302    0.063873  31315200    0.064731
# ...           ...         ...         ...         ...       ...         ...
# 10951  200.710007  201.360001  202.750000  199.699997  46742400  211.259995
# 10952  193.669998  195.270004  197.699997  193.460007  78432900  208.779999
# 10953  198.300003  200.210007  200.740005  197.429993  56288500  206.860001
# 10954  200.589996  200.419998  202.729996  199.899994  45339700  202.089996
# 10955  203.580002  199.949997  203.809998  198.509995  51477900  201.360001
#
#             min_5      max_10      min_10      max_20  ...  stochastic_fast  \
# 0        0.063445    0.065588    0.063016    0.066875  ...        69.988126
# 1        0.064302    0.065588    0.063445    0.066875  ...        69.988126
# 2        0.064302    0.065588    0.063445    0.065588  ...        59.989922
# 3        0.062159    0.065588    0.062159    0.065588  ...         9.998639
# 4        0.062159    0.065588    0.062159    0.065588  ...        44.435310
# ...           ...         ...         ...         ...  ...              ...
# 10951  201.360001  212.929993  198.270004  213.040634  ...        39.932454
# 10952  195.270004  212.929993  195.270004  213.040634  ...        10.853671
# 10953  195.270004  212.929993  195.270004  213.040634  ...        34.441412
# 10954  195.270004  212.330002  195.270004  213.040634  ...        33.984340
# 10955  195.270004  211.449997  195.270004  213.040634  ...        31.689412
#
#        stochastic_slow          %r       atr        cmo         cci  \
# 0            73.320630   42.871125  0.001194  33.333609   38.811075
# 1            66.655392   50.014527  0.001194  22.222340   38.747826
# 2            66.655392   66.676448  0.001194  -6.666682   31.136188
# 3            46.658896  100.000000  0.001133 -22.222077  -88.315492
# 4            38.141290   55.564690  0.001255   0.000000   -7.832802
# ...                ...         ...       ...        ...         ...
# 10951        49.496742   75.516075  5.175482  15.140598  -53.982399
# 10952        31.401398   91.162119  5.230436  -9.282185 -109.785045
# 10953        28.409179   67.041009  5.362205 -42.764716  -61.870892
# 10954        26.426474   66.015660  5.122784 -54.844385  -41.233342
# 10955        33.371722   66.717999  5.118286 -54.585577  -41.352619
#
#              mom      bias       wnr  target
# 0       0.003001  0.666650 -0.333332       0
# 1       0.001715  0.398934 -0.388888       0
# 2      -0.000429 -0.199567 -0.533333       0
# 3      -0.001715 -3.268648 -0.611110       1
# 4       0.000000 -0.600392 -0.500000       1
# ...          ...       ...       ...     ...
# 10951   4.128632 -3.011385 -0.424297       0
# 10952  -3.000000 -5.808633 -0.546411       1
# 10953 -10.579987 -2.930364 -0.713824       1
# 10954 -12.509995 -2.235578 -0.774222       0
# 10955 -12.380005 -1.872256 -0.772928       1
#
# [10956 rows x 52 columns]

# %% [markdown]
# ### PREDICTION (EXAMPLE USAGE)

# %%
stock_predictor = BaseModelStockPredictor(stock_data=stock_data, 
                                 model_name='hoeffdingtreeclassifier',
                                 drift_name='adwin',
                                 feature_selector_name='tstat',
                                 learning_threshold = 1000
                                 )
stock_predictor.prediction()
# Out:
# (0.525,
#     class  precision  recall     f1
#  0      0      0.519   0.537  0.528
#  1      1      0.531   0.513  0.522)

# %%
selected = stock_predictor.pipeline[1].selected_features
print("Selected features:", selected)
# Out:
# Selected features: ['upward_pressure', 'min_10', 'min_20', 'sma_10', 'min_5', 'open', 'sma_5', 'low', 'sma_20', 'max_5', 'min_40', 'high', 'max_10', 'close', 'sma_50']

# %%
def provide_hoeffdingtreeclassifier(args, args_values):
    models = []
    arg_strings = []

    for values in product(*args_values):
        kwargs = dict(zip(args, values))
        model = tree.HoeffdingTreeClassifier(**kwargs)
        models.append(model)

        # Create readable string representation
        args_str = ', '.join(f"{key}={value}" for key, value in kwargs.items())
        arg_strings.append(args_str)

    return models, arg_strings

def provide_extremelyfastdecisiontreeclassifier(args, args_values):
    models = []
    arg_strings = []

    for values in product(*args_values):
        kwargs = dict(zip(args, values))
        model = tree.ExtremelyFastDecisionTreeClassifier(**kwargs)
        models.append(model)

        # Create readable string representation
        args_str = ', '.join(f"{key}={value}" for key, value in kwargs.items())
        arg_strings.append(args_str)

    return models, arg_strings

# %%
result_rows = []
iterations = 5

for model_name in ['nochange', 'majorityclass', 'hoeffdingtreeclassifier', 'extremelyfastdecisiontreeclassifier']:

    if model_name == 'hoeffdingtreeclassifier':
        models, args_strs = provide_hoeffdingtreeclassifier(
            ['grace_period', 'max_depth', 'delta'],
            [[200], [None], [1e-7]]
        )
    if model_name == 'extremelyfastdecisiontreeclassifier':
        models, args_strs = provide_extremelyfastdecisiontreeclassifier(
            ['grace_period', 'max_depth', 'delta'],
            [[200], [None], [1e-7]]
        )

    if model_name in ['nochange', 'majorityclass', 'hoeffdingtreeclassifier', 'extremelyfastdecisiontreeclassifier']:

        for num_features in [5, 7, 10, 15, 20]:
        
            for feature_selector_name in ['selectkbest', 'tstat']:
    
                for model, model_args in zip(models, args_strs):
            
                    for drift_name in ['adwin', 'kswin', 'pagehinkley', 'bollingerband']:
            
                        for learning_threshold in [500]:
            
                            for iteration in range(iterations):
            
                                print('''
            model_name = {model_name}
            model_args = {model_args}
            drift_name = {drift_name}
            feature_selector_name = {feature_selector_name}
            num_features = {num_features}
            learning_threshold = {learning_threshold}
            iteration = {iteration}
                                    '''.format(
            model_name=model_name,
            model_args=model_args,
            drift_name=drift_name,
            feature_selector_name=feature_selector_name,
            num_features=num_features,
            learning_threshold=learning_threshold,
            iteration=iteration+1
            ))
                                
                                stock_predictor = BaseModelStockPredictor(stock_data=stock_data,
                                                model_name=model_name,
                                                drift_name=drift_name,
                                                feature_selector_name=feature_selector_name,
                                                num_features=num_features,
                                                learning_threshold = learning_threshold
                                                )
                                
                                accuracy, metrics_result = stock_predictor.prediction()
                                
                                result_rows.append([model_name, drift_name, feature_selector_name, num_features, learning_threshold, iteration+1, round(accuracy, 3), stock_predictor.drifts_detected, model_args, ticker])
                                print('accuracy = {:.4f}'.format(accuracy))

result_df = pd.DataFrame(result_rows, columns=['model_name', 'drift_name', 'feature_selector_name', 'num_features', 'learning_threshold', 'iteration', 'accuracy', 'drifts_detected', 'model_args', 'ticker'])
result_df.to_csv('results_df_selector_synthetic.csv', index=False)
# Out:
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = selectkbest
#             num_features = 5
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = selectkbest
#             num_features = 5
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = selectkbest
#             num_features = 5
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = selectkbest
#             num_features = 5
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = selectkbest
#             num_features = 5
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = selectkbest
#             num_features = 5
#             learning_threshold = 500
#             iteration = 1
# C:\Users\XXX\anaconda3\Lib\site-packages\scipy\stats\_axis_nan_policy.py:586: RuntimeWarning: ks_2samp: Exact calculation unsuccessful. Switching to method=asymp.
#   res = hypotest_fun_out(*samples, **kwds)
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = selectkbest
#             num_features = 5
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = selectkbest
#             num_features = 5
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = selectkbest
#             num_features = 5
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = selectkbest
#             num_features = 5
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = selectkbest
#             num_features = 5
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = selectkbest
#             num_features = 5
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = selectkbest
#             num_features = 5
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = selectkbest
#             num_features = 5
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = selectkbest
#             num_features = 5
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = selectkbest
#             num_features = 5
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = selectkbest
#             num_features = 5
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = selectkbest
#             num_features = 5
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = selectkbest
#             num_features = 5
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = selectkbest
#             num_features = 5
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = tstat
#             num_features = 5
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = tstat
#             num_features = 5
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = tstat
#             num_features = 5
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = tstat
#             num_features = 5
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = tstat
#             num_features = 5
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = tstat
#             num_features = 5
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = tstat
#             num_features = 5
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = tstat
#             num_features = 5
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = tstat
#             num_features = 5
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = tstat
#             num_features = 5
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = tstat
#             num_features = 5
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = tstat
#             num_features = 5
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = tstat
#             num_features = 5
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = tstat
#             num_features = 5
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = tstat
#             num_features = 5
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = tstat
#             num_features = 5
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = tstat
#             num_features = 5
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = tstat
#             num_features = 5
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = tstat
#             num_features = 5
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = tstat
#             num_features = 5
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = selectkbest
#             num_features = 7
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = selectkbest
#             num_features = 7
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = selectkbest
#             num_features = 7
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = selectkbest
#             num_features = 7
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = selectkbest
#             num_features = 7
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = selectkbest
#             num_features = 7
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = selectkbest
#             num_features = 7
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = selectkbest
#             num_features = 7
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = selectkbest
#             num_features = 7
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = selectkbest
#             num_features = 7
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = selectkbest
#             num_features = 7
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = selectkbest
#             num_features = 7
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = selectkbest
#             num_features = 7
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = selectkbest
#             num_features = 7
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = selectkbest
#             num_features = 7
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = selectkbest
#             num_features = 7
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = selectkbest
#             num_features = 7
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = selectkbest
#             num_features = 7
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = selectkbest
#             num_features = 7
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = selectkbest
#             num_features = 7
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = tstat
#             num_features = 7
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = tstat
#             num_features = 7
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = tstat
#             num_features = 7
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = tstat
#             num_features = 7
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = tstat
#             num_features = 7
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = tstat
#             num_features = 7
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = tstat
#             num_features = 7
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = tstat
#             num_features = 7
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = tstat
#             num_features = 7
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = tstat
#             num_features = 7
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = tstat
#             num_features = 7
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = tstat
#             num_features = 7
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = tstat
#             num_features = 7
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = tstat
#             num_features = 7
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = tstat
#             num_features = 7
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = tstat
#             num_features = 7
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = tstat
#             num_features = 7
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = tstat
#             num_features = 7
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = tstat
#             num_features = 7
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = tstat
#             num_features = 7
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = selectkbest
#             num_features = 10
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = selectkbest
#             num_features = 10
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = selectkbest
#             num_features = 10
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = selectkbest
#             num_features = 10
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = selectkbest
#             num_features = 10
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = selectkbest
#             num_features = 10
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = selectkbest
#             num_features = 10
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = selectkbest
#             num_features = 10
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = selectkbest
#             num_features = 10
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = selectkbest
#             num_features = 10
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = selectkbest
#             num_features = 10
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = selectkbest
#             num_features = 10
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = selectkbest
#             num_features = 10
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = selectkbest
#             num_features = 10
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = selectkbest
#             num_features = 10
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = selectkbest
#             num_features = 10
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = selectkbest
#             num_features = 10
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = selectkbest
#             num_features = 10
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = selectkbest
#             num_features = 10
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = selectkbest
#             num_features = 10
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = tstat
#             num_features = 10
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = tstat
#             num_features = 10
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = tstat
#             num_features = 10
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = tstat
#             num_features = 10
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = tstat
#             num_features = 10
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = tstat
#             num_features = 10
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = tstat
#             num_features = 10
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = tstat
#             num_features = 10
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = tstat
#             num_features = 10
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5000
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = tstat
#             num_features = 10
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = tstat
#             num_features = 10
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = tstat
#             num_features = 10
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = tstat
#             num_features = 10
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = tstat
#             num_features = 10
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = tstat
#             num_features = 10
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = tstat
#             num_features = 10
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = tstat
#             num_features = 10
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = tstat
#             num_features = 10
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = tstat
#             num_features = 10
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = tstat
#             num_features = 10
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = selectkbest
#             num_features = 15
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = selectkbest
#             num_features = 15
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = selectkbest
#             num_features = 15
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = selectkbest
#             num_features = 15
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = selectkbest
#             num_features = 15
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = selectkbest
#             num_features = 15
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = selectkbest
#             num_features = 15
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = selectkbest
#             num_features = 15
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = selectkbest
#             num_features = 15
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = selectkbest
#             num_features = 15
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = selectkbest
#             num_features = 15
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = selectkbest
#             num_features = 15
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = selectkbest
#             num_features = 15
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = selectkbest
#             num_features = 15
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = selectkbest
#             num_features = 15
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = selectkbest
#             num_features = 15
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = selectkbest
#             num_features = 15
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = selectkbest
#             num_features = 15
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = selectkbest
#             num_features = 15
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = selectkbest
#             num_features = 15
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = tstat
#             num_features = 15
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = tstat
#             num_features = 15
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = tstat
#             num_features = 15
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5010
#
#             model_name = nochange
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = tstat
# ...
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5160
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = tstat
#             num_features = 15
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5160
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = tstat
#             num_features = 15
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5160
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = tstat
#             num_features = 15
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5160
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = tstat
#             num_features = 15
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5160
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = selectkbest
#             num_features = 20
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5100
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = selectkbest
#             num_features = 20
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5100
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = selectkbest
#             num_features = 20
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5100
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = selectkbest
#             num_features = 20
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5100
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = selectkbest
#             num_features = 20
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5100
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = selectkbest
#             num_features = 20
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5110
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = selectkbest
#             num_features = 20
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5030
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = selectkbest
#             num_features = 20
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5120
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = selectkbest
#             num_features = 20
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5120
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = selectkbest
#             num_features = 20
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5010
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = selectkbest
#             num_features = 20
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5090
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = selectkbest
#             num_features = 20
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5090
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = selectkbest
#             num_features = 20
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5090
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = selectkbest
#             num_features = 20
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5090
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = selectkbest
#             num_features = 20
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5090
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = selectkbest
#             num_features = 20
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5090
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = selectkbest
#             num_features = 20
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5090
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = selectkbest
#             num_features = 20
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5090
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = selectkbest
#             num_features = 20
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5090
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = selectkbest
#             num_features = 20
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5090
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = tstat
#             num_features = 20
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5170
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = tstat
#             num_features = 20
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5170
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = tstat
#             num_features = 20
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5170
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = tstat
#             num_features = 20
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5170
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = adwin
#             feature_selector_name = tstat
#             num_features = 20
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5170
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = tstat
#             num_features = 20
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5240
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = tstat
#             num_features = 20
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5210
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = tstat
#             num_features = 20
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5190
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = tstat
#             num_features = 20
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5210
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = kswin
#             feature_selector_name = tstat
#             num_features = 20
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5220
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = tstat
#             num_features = 20
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5210
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = tstat
#             num_features = 20
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5210
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = tstat
#             num_features = 20
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5210
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = tstat
#             num_features = 20
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5210
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = pagehinkley
#             feature_selector_name = tstat
#             num_features = 20
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5210
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = tstat
#             num_features = 20
#             learning_threshold = 500
#             iteration = 1
#
# accuracy = 0.5160
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = tstat
#             num_features = 20
#             learning_threshold = 500
#             iteration = 2
#
# accuracy = 0.5160
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = tstat
#             num_features = 20
#             learning_threshold = 500
#             iteration = 3
#
# accuracy = 0.5160
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = tstat
#             num_features = 20
#             learning_threshold = 500
#             iteration = 4
#
# accuracy = 0.5160
#
#             model_name = extremelyfastdecisiontreeclassifier
#             model_args = grace_period=200, max_depth=None, delta=1e-07
#             drift_name = bollingerband
#             feature_selector_name = tstat
#             num_features = 20
#             learning_threshold = 500
#             iteration = 5
#
# accuracy = 0.5160
