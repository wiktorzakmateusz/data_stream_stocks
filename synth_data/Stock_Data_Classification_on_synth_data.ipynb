# %%
import pandas as pd
import numpy as np
from DataLoader import DataLoader, SyntheticDataLoader
from river import stream
from river import tree
from river import metrics
from river import preprocessing
from river import feature_selection
from river import drift
from river import stats
from river import ensemble
from river import forest
from collections import deque, Counter
from river import base
from typing import Dict, List
import math
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.feature_selection import SelectKBest, f_classif, VarianceThreshold
from sklearn.neural_network import MLPClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
import warnings
from itertools import product
import matplotlib.pyplot as plt
from pandasql import sqldf
import seaborn as sns
import matplotlib.pyplot as plt
from classification import TStatFeatureSelector

pd.options.display.max_columns = 500


class BollingerBandDriftDetector:
    def __init__(self, window_size=20, num_std=3.5, next_drift_delay=100):
        self.window_size = window_size
        self.num_std = num_std
        self.values = deque(maxlen=window_size)
        self.drift_detected = False
        self.next_drift_delay = next_drift_delay
        self.current_next_drift_delay = 0

    def update(self, value: float):
        self.values.append(value)
        self.drift_detected = False  # Reset flag
        self.current_next_drift_delay = max(0, self.current_next_drift_delay - 1)
        
        if len(self.values) < self.window_size:
            return  # Not enough data yet
        
        mean = np.mean(self.values)
        std = np.std(self.values)
        upper_band = mean + self.num_std * std
        lower_band = mean - self.num_std * std

        # If current value is outside bands -> drift
        if (value > upper_band or value < lower_band) and self.current_next_drift_delay == 0:
            self.drift_detected = True
            self.current_next_drift_delay = self.next_drift_delay # min of instances between next drifts

class FixedSizeBuffer:
    def __init__(self, max_size, num_features):
        self.max_size = max_size
        self.buffer = np.empty((0, num_features))
        self.labels = []

    def append(self, x):
        if len(self.buffer) >= self.max_size:
            self.buffer = np.delete(self.buffer, 0, axis=0)
            self.labels.pop(0)
        self.buffer = np.vstack([self.buffer, x])

    def append_label(self, y):
        self.labels.append(y)

    def get_data(self):
        return self.buffer, np.array(self.labels)

class StockPredictor:

    def __init__(self, stock_data, model_name, drift_name, feature_selector_name, 
                 provided_model=None, provided_detector=None, provided_feature_selector=None,
                 learning_threshold = 1000):
        self.stock_data = stock_data
        self.data_stream = StockPredictor.ohlc_stream(stock_data)
        self.metric = metrics.ClassificationReport()
        self.learning_threshold = learning_threshold
        self.drifts_detected = 0

        self.model_name = model_name
        self.provided_model = provided_model
        if provided_model:
            self.model = provided_model
            self.is_incremental = hasattr(provided_model, 'learn_one')
        else:
            self.model, self.is_incremental = StockPredictor.get_model(model_name)

        if self.is_incremental:
            self.feature_selector_name = feature_selector_name
            self.feature_selector = provided_feature_selector or StockPredictor.get_feature_selector(feature_selector_name)
            self.pipeline = StockPredictor.get_pipeline(self.model, self.feature_selector)
            
        else:
            self.feature_selector_name = feature_selector_name
            self.feature_selector = provided_feature_selector or StockPredictor.get_feature_selector(feature_selector_name)
            self.pipeline = StockPredictor.get_sklearn_pipeline(self.model, self.feature_selector)

        self.drift_name = drift_name
        self.drift_detector = provided_detector or StockPredictor.get_drift_detector(drift_name)

    @staticmethod
    def ohlc_stream(df):
        for _, row in df.iterrows():
            features = row.iloc[:-1].to_dict()
            yield features, row['target']

    @staticmethod
    def get_model(name: str):
        name = name.lower()
        if name == 'hoeffdingtreeclassifier':
            return tree.HoeffdingTreeClassifier(), True
        if name == 'extremelyfastdecisiontreeclassifier':
            return tree.ExtremelyFastDecisionTreeClassifier(), True
        else:
            raise ValueError(f"Unknown model")

    @staticmethod
    def get_drift_detector(name: str):
        name = name.lower()
        if name == "adwin":
            return drift.ADWIN()
        elif name == "kswin":
            return drift.KSWIN()
        elif name == "dummydriftdetector":
            return drift.DummyDriftDetector()
        elif name == "pagehinkley":
            return drift.PageHinkley()
        elif name == 'bollingerband':
            return BollingerBandDriftDetector()
        else:
            raise ValueError(f"Unknown detector")

    @staticmethod
    def get_feature_selector(name: str):
        name = name.lower()
        if name == "selectkbest":
            return feature_selection.SelectKBest(similarity=stats.PearsonCorr(), k=15)
        elif name == 'selectkbest_sklearn':
            return SelectKBest(score_func=f_classif, k=15)
        elif name == 'tstat':
            return TStatFeatureSelector(k=15, update_interval=100)
        elif name == 'ewa':
            return EWA(alpha=0.3, n=15)
        else:
            raise ValueError(f"Unknown selector")

    @staticmethod
    def get_pipeline(model, feature_selector):
        scaler = preprocessing.StandardScaler()
        pipeline = scaler | feature_selector | model
        return pipeline

    @staticmethod
    def get_sklearn_pipeline(model, feature_selector):
        scaler = MinMaxScaler()
        selector = feature_selector
        model = model
        pipeline = Pipeline([
            ('scaler', scaler),
            ('selector', selector),
            ('mlp', model)
        ])
    
        return pipeline
    
    def prediction(self):

        if self.is_incremental:
            for i, (x, y) in enumerate(self.data_stream):
                close_value = float(self.stock_data.loc[i, 'close'])
                if i >= self.learning_threshold:

                    y_pred = self.pipeline.predict_one(x)
                    self.pipeline.learn_one(x, y)

                    error = int(y_pred != y) if y_pred is not None else 0
                    if self.drift_name == 'bollingerband':
                        self.drift_detector.update(close_value)
                    else:
                        self.drift_detector.update(error)

                    if y_pred is not None:
                        self.metric.update(y, y_pred)

                    if self.drift_detector.drift_detected:
                        self.drifts_detected += 1
                        # print(f'Drift detected at index {i}! ({self.drift_name})')

                        # resets model
                        if self.provided_model:
                            self.model = self.provided_model
                        else:
                            self.model, _ = StockPredictor.get_model(self.model_name)

                        self.pipeline = StockPredictor.get_pipeline(self.model, self.feature_selector)
        
        else:

            buffer = FixedSizeBuffer(max_size=self.learning_threshold, num_features=self.stock_data.shape[1] - 1)
            for i, (x, y) in enumerate(self.data_stream):
                close_value = float(self.stock_data.loc[i, 'close'])
                x_array = np.array(list(x.values())).reshape(1, -1)
                buffer.append(x_array[0])
                buffer.append_label(y)
                
                if i >= self.learning_threshold and (i % self.learning_threshold == 0 or self.drift_detector.drift_detected):
                    X_train, y_train = buffer.get_data()
                    with warnings.catch_warnings():
                        warnings.simplefilter("ignore")
                        self.pipeline.fit(X_train, y_train) # MLP produces warnings!

                if i >= self.learning_threshold:
                    with warnings.catch_warnings():
                        warnings.simplefilter("ignore")
                        y_pred = self.pipeline.predict(x_array)[0]
                    error = int(y_pred != y)
                    if self.drift_name == 'bollingerband':
                        self.drift_detector.update(close_value)
                    else:
                        self.drift_detector.update(error)
                        
                    self.metric.update(y, y_pred)

                    if self.drift_detector.drift_detected:
                        self.drifts_detected += 1
                        # print(f'Drift detected at index {i}! ({self.drift_name})')


        accuracy, metrics_result = self.get_metrics()
        # print(f'accuracy: {accuracy}')
        # display(metrics_result)
        return accuracy, metrics_result

    def get_metrics(self):

        classes = sorted(self.metric.cm.classes)

        for c in classes:
            if c not in self.metric._f1s:
                self.metric._f1s[c] = metrics.F1(cm=self.metric.cm, pos_val=c)
        
        accuracy = round(self.metric._accuracy.get(), 3)

        # print(self.metric._f1s)
        metrics_result = pd.DataFrame([ [0, self.metric._f1s[0].precision.get(), self.metric._f1s[0].recall.get(), self.metric._f1s[0].get()],
                                        [1, self.metric._f1s[1].precision.get(), self.metric._f1s[1].recall.get(), self.metric._f1s[1].get()]],
                                        columns=['class', 'precision', 'recall', 'f1'])
        
        metrics_result = metrics_result.round(3)

        return accuracy, metrics_result

class NoChangeClassifier(base.Classifier):
    def __init__(self):
        self.last_label = None

    def learn_one(self, x, y):
        self.last_label = y
        return self

    def predict_one(self, x):
        return self.last_label

class MajorityClassClassifier(base.Classifier):
    def __init__(self, window_size=100):
        self.window_size = window_size
        self.window = deque()
        self.class_counts = Counter()
        self.majority_class = None

    def learn_one(self, x, y):
        self.window.append(y)
        self.class_counts[y] += 1

        if len(self.window) > self.window_size:
            old_y = self.window.popleft()
            self.class_counts[old_y] -= 1
            if self.class_counts[old_y] == 0:
                del self.class_counts[old_y]

        if self.class_counts:
            self.majority_class = self.class_counts.most_common(1)[0][0]

        return self

    def predict_one(self, x):
        return self.majority_class

class StockPredictor_Naive:

    def __init__(self, stock_data, model_name, drift_name, provided_model=None, provided_detector=None, learning_threshold = 1000):
        self.stock_data = stock_data
        self.data_stream = StockPredictor_Naive.ohlc_stream(stock_data)
        self.metric = metrics.ClassificationReport()
        self.learning_threshold = learning_threshold
        self.drifts_detected = 0

        self.model_name = model_name
        self.provided_model = provided_model

        if provided_model:
            self.model = provided_model
        else:
            self.model= StockPredictor_Naive.get_model(model_name)

        self.drift_name = drift_name
        self.drift_detector = provided_detector or StockPredictor_Naive.get_drift_detector(drift_name)
        self.drift_days = []

    @staticmethod
    def ohlc_stream(df):
        for _, row in df.iterrows():
            features = row.iloc[:-1].to_dict()
            yield features, row['target']

    @staticmethod
    def get_model(name: str):
        name = name.lower()
        if name == 'nochange':
            return NoChangeClassifier()
        if name == 'majorityclass':
            return MajorityClassClassifier()
        else:
            raise ValueError(f"Unknown model")

    @staticmethod
    def get_drift_detector(name: str):
        name = name.lower()
        if name == "adwin":
            return drift.ADWIN()
        elif name == "kswin":
            return drift.KSWIN()
        elif name == "dummydriftdetector":
            return drift.DummyDriftDetector()
        elif name == "pagehinkley":
            return drift.PageHinkley()
        elif name == 'bollingerband':
            return BollingerBandDriftDetector()
        else:
            raise ValueError(f"Unknown detector")

    def prediction(self):
        for i, (x, y) in enumerate(self.data_stream):
            close_value = float(self.stock_data.loc[i, 'close'])

            if i >= self.learning_threshold:
                y_pred = self.model.predict_one(x)
                
                self.model.learn_one(x, y)

                error = int(y_pred != y) if y_pred is not None else 0
                if self.drift_name == 'bollingerband':
                    self.drift_detector.update(close_value)
                else:
                    self.drift_detector.update(error)

                if y_pred is not None:
                    self.metric.update(y, y_pred)

                if self.drift_detector.drift_detected:
                    self.drifts_detected += 1
                    # print(f'Drift detected at index {i}! ({self.drift_name})')
                    self.drift_days.append(i)

                    # resets model
                    if self.provided_model:
                        self.model = self.provided_model
                    else:
                        self.model, _ = StockPredictor_Naive.get_model(self.model_name)        

        accuracy, metrics_result = self.get_metrics()
        # print(f'accuracy: {accuracy}')
        # display(metrics_result)
        return accuracy, metrics_result

    def get_metrics(self):

        classes = sorted(self.metric.cm.classes)

        for c in classes:
            if c not in self.metric._f1s:
                self.metric._f1s[c] = metrics.F1(cm=self.metric.cm, pos_val=c)
        
        accuracy = round(self.metric._accuracy.get(), 3)

        # print(self.metric._f1s)
        metrics_result = pd.DataFrame([ [0, self.metric._f1s[0].precision.get(), self.metric._f1s[0].recall.get(), self.metric._f1s[0].get()],
                                        [1, self.metric._f1s[1].precision.get(), self.metric._f1s[1].recall.get(), self.metric._f1s[1].get()]],
                                        columns=['class', 'precision', 'recall', 'f1'])
        
        metrics_result = metrics_result.round(3)

        return accuracy, metrics_result

# %% [markdown]
# ### DATA LOADING

# %%
dataLoader = SyntheticDataLoader() 
stock_data, regimes = dataLoader.pipeline(n_days=5000, n_drifts=5, seed=2)

plt.figure(figsize=(12, 4))
for regime in np.unique(regimes):
    subset = [i for i, x in enumerate(regimes) if x == regime]
    plt.plot(subset, stock_data.loc[subset, 'close'], label=f"Regime {regime}")
# plt.title("Synthetic data stream with drifts")
plt.xlabel("Day")
plt.ylabel("Close Price")
plt.legend()
plt.grid(True)
plt.savefig('result_df_images_to_report/synthetic_data_5_drifts.png')
plt.show()

# %%
stock_data
# Out:
#             open        high         low       close       max_5       min_5  \
# 0     130.016794  130.623437  129.782499  130.186442  130.186442  129.491172
# 1     130.616480  130.886605  130.111349  130.442917  130.442917  129.491172
# 2     129.642491  129.842800  128.786882  129.004677  130.442917  129.004677
# 3     128.645644  129.241145  128.455586  129.192273  130.442917  129.004677
# 4     129.662921  130.049888  129.437877  129.590900  130.442917  129.004677
# ...          ...         ...         ...         ...         ...         ...
# 4742   66.561699   66.715509   66.464297   66.600380    67.26925   66.466444
# 4743   67.851186   67.985224   67.707527   67.899426   67.899426   66.475287
# 4744   68.142801   68.615385   68.041876   68.411667   68.411667   66.475287
# 4745   68.000964   68.108641   67.849617   67.927055   68.411667    66.60038
# 4746   67.846429   68.056214   67.728738   67.964561   68.411667    66.60038
#
#           max_10      min_10      max_20     min_20      max_40      min_40  \
# 0     130.186442  128.422863   132.07426   128.3814  132.371154  126.669141
# 1     130.442917  128.465842  131.533249   128.3814  132.371154  126.669141
# 2     130.442917  128.715557  131.382646   128.3814  132.371154  126.757608
# 3     130.442917  128.715557  131.211785   128.3814  132.371154  126.757608
# 4     130.442917  129.004677  131.211785   128.3814  132.371154  127.098644
# ...          ...         ...         ...        ...         ...         ...
# 4742    67.26925   65.120797    67.26925  62.644448   72.723699   62.644448
# 4743   67.899426   65.120797   67.899426  62.644448   72.723699   62.644448
# 4744   68.411667   65.120797   68.411667  63.810725   72.668929   62.644448
# 4745   68.411667   65.120797   68.411667  63.954686   72.668929   62.644448
# 4746   68.411667    65.15391   68.411667  63.954686   71.006899   62.644448
#
#           max_80      min_80     max_125     min_125     max_250    min_250  \
# 0     132.371154  120.659791  132.371154  109.186938  132.371154  97.932181
# 1     132.371154  120.659791  132.371154  109.186938  132.371154  97.932181
# 2     132.371154  120.659791  132.371154  109.186938  132.371154  97.932181
# 3     132.371154  120.759907  132.371154  109.186938  132.371154  97.932181
# 4     132.371154  120.759907  132.371154  109.186938  132.371154  97.932181
# ...          ...         ...         ...         ...         ...        ...
# 4742   83.539802   62.644448   89.276732   62.644448  115.369232  62.644448
# 4743   83.036313   62.644448   86.436592   62.644448  115.369232  62.644448
# 4744   82.682726   62.644448   86.269964   62.644448  115.369232  62.644448
# 4745   82.359839   62.644448   86.269964   62.644448  115.369232  62.644448
# 4746   82.359839   62.644448   86.269964   62.644448  115.369232  62.644448
#
#          max_500    min_500 max_lifetime min_lifetime       sma_5      sma_10  \
# 0     132.371154  97.932181   132.371154    97.932181  129.761813  129.250336
# 1     132.371154  97.932181   132.371154    97.932181  129.929771  129.452341
# 2     132.371154  97.932181   132.371154    97.932181  129.824691  129.506225
# 3     132.371154  97.932181   132.371154    97.932181  129.764911  129.527869
# 4     132.371154  97.932181   132.371154    97.932181  129.683441  129.615403
# ...          ...        ...          ...          ...         ...         ...
# 4742  152.689542  62.644448   224.919637    57.772038   66.688320   66.201974
# 4743  152.689542  62.644448   224.919637    57.772038   66.974916   66.398479
# 4744  152.689542  62.644448   224.919637    57.772038   67.203400   66.601683
# 4745  152.689542  62.644448   224.919637    57.772038   67.493753   66.795445
# 4746  152.689542  62.644448   224.919637    57.772038   67.760618   67.079822
#
#           sma_20      sma_50     sma_100     sma_200  daily_return  \
# 0     129.775209  129.005107  125.053250  116.136893      0.001448
# 1     129.693642  129.062061  125.222959  116.275566      0.001970
# 2     129.567213  129.075922  125.373424  116.405312     -0.011026
# 3     129.457694  129.104884  125.521974  116.532023      0.001454
# 4     129.444953  129.130164  125.666635  116.661819      0.003086
# ...          ...         ...         ...         ...           ...
# 4742   65.254679   68.202096   74.842232   84.774851     -0.000448
# 4743   65.473149   68.047141   74.706562   84.563652      0.019505
# 4744   65.761510   67.899529   74.568468   84.355549      0.007544
# 4745   65.967326   67.764571   74.434768   84.151158     -0.007084
# 4746   66.166529   67.630777   74.291736   83.950101      0.000552
#
#       1_week_return  2_weeks_return  1_month_return  6_months_return  \
# 0          0.008305        0.013318       -0.016504         0.183550
# 1          0.006480        0.015730       -0.012352         0.180935
# 2         -0.004056        0.004194       -0.019224         0.167665
# 3         -0.002308        0.001678       -0.016672         0.161943
# 4         -0.003133        0.006801       -0.001962         0.173095
# ...             ...             ...             ...              ...
# 4742       0.022201        0.015113        0.034642        -0.223486
# 4743       0.021559        0.029803        0.068777        -0.203757
# 4744       0.016983        0.030613        0.092063        -0.187028
# 4745       0.021839        0.029363        0.064508        -0.189287
# 4746       0.020026        0.043669        0.062270        -0.178468
#
#       12_months_return  day_variation  day_change  downward_pressure  \
# 0             0.314754       0.006480    0.001305          -0.003345
# 1             0.304859       0.005958   -0.001329          -0.003390
# 2             0.300939       0.008199   -0.004920          -0.006455
# 3             0.306966       0.006115    0.004249          -0.000378
# 4             0.306122       0.004728   -0.000555          -0.003529
# ...                ...            ...         ...                ...
# 4742         -0.403297       0.003780    0.000581          -0.001726
# 4743         -0.389376       0.004101    0.000711          -0.001262
# 4744         -0.384902       0.008429    0.003946          -0.002969
# 4745         -0.388796       0.003818   -0.001087          -0.002666
# 4746         -0.381875       0.004835    0.001741          -0.001347
#
#       upward_pressure        rsi      macd       ppo  stochastic_fast  \
# 0            0.003112  49.753498  0.158227  0.122264        83.638037
# 1            0.002548  51.388185  0.215986  0.166797        86.114476
# 2            0.001691  44.829009  0.144046  0.111272        41.103851
# 3            0.005735  58.936478  0.101006  0.078037        39.243918
# 4            0.001182  61.520288  0.097934  0.075656        53.538053
# ...               ...        ...       ...       ...              ...
# 4742         0.002047  66.775175 -0.331885 -0.499605        71.671541
# 4743         0.002834  74.320140 -0.163569 -0.245827        97.151704
# 4744         0.005435  72.239224  0.011029  0.016541        94.366767
# 4745         0.001141  65.716179  0.109038  0.163304        80.966211
# 4746         0.003482  65.725244  0.187575  0.280557        82.003343
#
#       stochastic_slow         %r       atr        cmo         cci       mom  \
# 0           70.626587  17.302786  0.864686  66.823131   26.624439  1.711053
# 1           82.312878  16.792489  0.861657  73.070672   53.957099  2.020053
# 2           70.285455  83.334561  0.899066  12.953442  -26.944873  0.538835
# 3           55.487415  69.696390  0.820393   5.640196  -40.164577  0.216436
# 4           44.628608  53.298861  0.848541  22.017142   19.658790  0.875342
# ...               ...        ...       ...        ...         ...       ...
# 4742        70.841411  40.351753  0.674795  19.227579   53.158523  0.991532
# 4743        80.425197   2.873143  0.747634  32.054495  100.904789  1.965048
# 4744        87.730004   5.633233  0.712365  32.789046  117.724801  2.032047
# 4745        90.828227  19.033789  0.709129  30.796160   94.274562  1.937621
# 4746        85.778773  17.996657  0.718043  52.077563   85.408563  2.843764
#
#           bias       wnr  target
# 0     0.724258 -0.165884       1
# 1     0.765204 -0.134647       0
# 2    -0.387277 -0.435233       1
# 3    -0.259092 -0.471799       1
# 4    -0.018904 -0.389914       1
# ...        ...       ...     ...
# 4742  0.601805 -0.403862       1
# 4743  2.260515 -0.339728       1
# 4744  2.717624 -0.336055       0
# 4745  1.694141 -0.346019       1
# 4746  1.318935 -0.239612       1
#
# [4747 rows x 51 columns]

# %% [markdown]
# ### GRID SEARCH REPORT

# %%
# Drift detectors - default values for overview
adwin_detector = drift.ADWIN(delta=0.002, clock=32, max_buckets=5, min_window_length=5, grace_period=10)
kswin_detector = drift.KSWIN(alpha = 0.005, window_size = 100, stat_size = 30)
page_hinley_detector = drift.PageHinkley(min_instances = 30, delta = 0.005, threshold = 50.0, alpha = 0.9999, mode = "both")
bollinger_band_detector = BollingerBandDriftDetector(window_size=20, num_std=3.5, next_drift_delay=100)

# %%
def provide_drift_detectors(detector_class, args, args_values):
    detectors = []
    arg_strings = []

    for values in product(*args_values):
        kwargs = dict(zip(args, values))
        detector = detector_class(**kwargs)
        detectors.append(detector)

        args_str = ', '.join(f"{key}={value}" for key, value in kwargs.items())
        arg_strings.append(args_str)

    return detectors, arg_strings

# %%
result_rows = []
iterations = 3
feature_selector_name = 'tstat'
learning_threshold = 0

for model_name in ['hoeffdingtreeclassifier', 'extremelyfastdecisiontreeclassifier', 'nochange', 'majorityclass']:

    if model_name == 'hoeffdingtreeclassifier':
        model = tree.HoeffdingTreeClassifier(grace_period=100, max_depth=12)

    if model_name == 'extremelyfastdecisiontreeclassifier':
        model = tree.ExtremelyFastDecisionTreeClassifier()
    
    if model_name == 'nochange':
        model = NoChangeClassifier()
    
    if model_name == 'majorityclass':
        model = MajorityClassClassifier(window_size=500)
    
    if model_name in ['hoeffdingtreeclassifier', 'extremelyfastdecisiontreeclassifier', 'nochange', 'majorityclass']:
    
        for drift_name in ['adwin', 'kswin', 'pagehinkley', 'bollingerband']:

            if drift_name == 'adwin':
                drift_detectors, args = provide_drift_detectors(
                    drift.ADWIN,
                    ['delta', 'clock', 'max_buckets',  'grace_period'],
                    [[0.01, 0.002], [1, 10, 32], [5, 3], [10]]
                )
            if drift_name == 'kswin':
                drift_detectors, args = provide_drift_detectors(
                    drift.KSWIN,
                    ['alpha', 'window_size', 'stat_size'],
                    [[0.01, 0.005, 0.01], [100, 200], [20, 30, 40]]
                )
            if drift_name == 'pagehinkley':
                drift_detectors, args = provide_drift_detectors(
                    drift.PageHinkley,
                    [ 'delta', 'threshold', 'alpha', 'mode'],
                    [ [0.001, 0.005, 0.01], [30.0, 50.0, 100.0], [0.99, 0.9999], ['both', 'up', 'down']]
                )
            if drift_name == 'bollingerband':
                drift_detectors, args = provide_drift_detectors(
                    BollingerBandDriftDetector,
                    ['window_size', 'num_std', 'next_drift_delay'],
                    [[20, 50, 100, 200], [2, 2.5, 3., 3.5], [20, 50, 100]]
                )

            for drift_detector, drift_args in zip(drift_detectors, args):
                for iteration in range(iterations):

                    print('''
model_name = {model_name}
drift_name = {drift_name}
drift_args = {drift_args}
iteration = {iteration}
                    '''.format(
model_name=model_name,
drift_name=drift_name,
drift_args=drift_args,
iteration=iteration+1
        ))
                    if model_name not in ['nochange', 'majorityclass']:        
                        stock_predictor = StockPredictor(stock_data=stock_data,
                                        model_name=model_name,
                                        provided_model=model,
                                        drift_name=drift_name,
                                        feature_selector_name=feature_selector_name,
                                        learning_threshold = learning_threshold,
                                        provided_detector=drift_detector
                                        )
                    else:
                        stock_predictor = StockPredictor_Naive(stock_data=stock_data,
                                                            model_name=model_name,
                                                            provided_model=model,
                                                            drift_name=drift_name,
                                                            learning_threshold = learning_threshold                                                        
                                                            )
                    
                    accuracy, metrics_result = stock_predictor.prediction()
                    
                    result_rows.append([model_name, drift_name, feature_selector_name, learning_threshold, iteration+1, round(accuracy, 3), stock_predictor.drifts_detected, drift_args])
                    print('accuracy = {:.4f}'.format(accuracy))

result_df = pd.DataFrame(result_rows, columns=['model_name', 'drift_name', 'feature_selector_name', 'learning_threshold', 'iteration', 'accuracy', 'drifts_detected', 'drift_args'])
result_df.to_csv('results_df_synth_dataset.csv', index=False)
# Out:
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.01, clock=1, max_buckets=5, grace_period=10
# iteration = 1
#
# accuracy = 0.5260
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.01, clock=1, max_buckets=5, grace_period=10
# iteration = 2
#
# accuracy = 0.5290
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.01, clock=1, max_buckets=5, grace_period=10
# iteration = 3
#
# accuracy = 0.5300
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.01, clock=1, max_buckets=3, grace_period=10
# iteration = 1
#
# accuracy = 0.5330
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.01, clock=1, max_buckets=3, grace_period=10
# iteration = 2
#
# accuracy = 0.5330
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.01, clock=1, max_buckets=3, grace_period=10
# iteration = 3
#
# accuracy = 0.5330
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.01, clock=10, max_buckets=5, grace_period=10
# iteration = 1
#
# accuracy = 0.5310
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.01, clock=10, max_buckets=5, grace_period=10
# iteration = 2
#
# accuracy = 0.5310
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.01, clock=10, max_buckets=5, grace_period=10
# iteration = 3
#
# accuracy = 0.5320
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.01, clock=10, max_buckets=3, grace_period=10
# iteration = 1
#
# accuracy = 0.5390
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.01, clock=10, max_buckets=3, grace_period=10
# iteration = 2
#
# accuracy = 0.5260
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.01, clock=10, max_buckets=3, grace_period=10
# iteration = 3
#
# accuracy = 0.5340
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.01, clock=32, max_buckets=5, grace_period=10
# iteration = 1
#
# accuracy = 0.5010
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.01, clock=32, max_buckets=5, grace_period=10
# iteration = 2
#
# accuracy = 0.5020
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.01, clock=32, max_buckets=5, grace_period=10
# iteration = 3
#
# accuracy = 0.5060
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.01, clock=32, max_buckets=3, grace_period=10
# iteration = 1
#
# accuracy = 0.4990
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.01, clock=32, max_buckets=3, grace_period=10
# iteration = 2
#
# accuracy = 0.4930
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.01, clock=32, max_buckets=3, grace_period=10
# iteration = 3
#
# accuracy = 0.4960
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.002, clock=1, max_buckets=5, grace_period=10
# iteration = 1
#
# accuracy = 0.4990
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.002, clock=1, max_buckets=5, grace_period=10
# iteration = 2
#
# accuracy = 0.5000
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.002, clock=1, max_buckets=5, grace_period=10
# iteration = 3
#
# accuracy = 0.5020
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.002, clock=1, max_buckets=3, grace_period=10
# iteration = 1
#
# accuracy = 0.5020
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.002, clock=1, max_buckets=3, grace_period=10
# iteration = 2
#
# accuracy = 0.5030
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.002, clock=1, max_buckets=3, grace_period=10
# iteration = 3
#
# accuracy = 0.5030
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.002, clock=10, max_buckets=5, grace_period=10
# iteration = 1
#
# accuracy = 0.5010
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.002, clock=10, max_buckets=5, grace_period=10
# iteration = 2
#
# accuracy = 0.4890
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.002, clock=10, max_buckets=5, grace_period=10
# iteration = 3
#
# accuracy = 0.4990
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.002, clock=10, max_buckets=3, grace_period=10
# iteration = 1
#
# accuracy = 0.4990
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.002, clock=10, max_buckets=3, grace_period=10
# iteration = 2
#
# accuracy = 0.5010
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.002, clock=10, max_buckets=3, grace_period=10
# iteration = 3
#
# accuracy = 0.5020
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.002, clock=32, max_buckets=5, grace_period=10
# iteration = 1
#
# accuracy = 0.5020
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.002, clock=32, max_buckets=5, grace_period=10
# iteration = 2
#
# accuracy = 0.5030
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.002, clock=32, max_buckets=5, grace_period=10
# iteration = 3
#
# accuracy = 0.5030
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.002, clock=32, max_buckets=3, grace_period=10
# iteration = 1
#
# accuracy = 0.5030
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.002, clock=32, max_buckets=3, grace_period=10
# iteration = 2
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = adwin
# drift_args = delta=0.002, clock=32, max_buckets=3, grace_period=10
# iteration = 3
#
# accuracy = 0.5020
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=100, stat_size=20
# iteration = 1
#
# accuracy = 0.5060
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=100, stat_size=20
# iteration = 2
#
# accuracy = 0.4990
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=100, stat_size=20
# iteration = 3
#
# accuracy = 0.5010
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=100, stat_size=30
# iteration = 1
#
# accuracy = 0.5290
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=100, stat_size=30
# iteration = 2
#
# accuracy = 0.5330
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=100, stat_size=30
# iteration = 3
#
# accuracy = 0.5410
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=100, stat_size=40
# iteration = 1
#
# accuracy = 0.5160
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=100, stat_size=40
# iteration = 2
#
# accuracy = 0.5130
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=100, stat_size=40
# iteration = 3
#
# accuracy = 0.5170
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=200, stat_size=20
# iteration = 1
#
# accuracy = 0.5010
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=200, stat_size=20
# iteration = 2
#
# accuracy = 0.5380
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=200, stat_size=20
# iteration = 3
#
# accuracy = 0.5500
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=200, stat_size=30
# iteration = 1
#
# accuracy = 0.5380
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=200, stat_size=30
# iteration = 2
#
# accuracy = 0.5380
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=200, stat_size=30
# iteration = 3
#
# accuracy = 0.5270
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=200, stat_size=40
# iteration = 1
#
# accuracy = 0.5200
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=200, stat_size=40
# iteration = 2
#
# accuracy = 0.5440
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=200, stat_size=40
# iteration = 3
#
# accuracy = 0.5390
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.005, window_size=100, stat_size=20
# iteration = 1
#
# accuracy = 0.5440
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.005, window_size=100, stat_size=20
# iteration = 2
#
# accuracy = 0.5020
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.005, window_size=100, stat_size=20
# iteration = 3
#
# accuracy = 0.5280
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.005, window_size=100, stat_size=30
# iteration = 1
#
# accuracy = 0.5220
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.005, window_size=100, stat_size=30
# iteration = 2
#
# accuracy = 0.5240
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.005, window_size=100, stat_size=30
# iteration = 3
#
# accuracy = 0.5440
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.005, window_size=100, stat_size=40
# iteration = 1
#
# accuracy = 0.5380
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.005, window_size=100, stat_size=40
# iteration = 2
#
# accuracy = 0.5280
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.005, window_size=100, stat_size=40
# iteration = 3
#
# accuracy = 0.5210
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.005, window_size=200, stat_size=20
# iteration = 1
#
# accuracy = 0.5130
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.005, window_size=200, stat_size=20
# iteration = 2
#
# accuracy = 0.5190
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.005, window_size=200, stat_size=20
# iteration = 3
#
# accuracy = 0.5300
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.005, window_size=200, stat_size=30
# iteration = 1
#
# accuracy = 0.5020
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.005, window_size=200, stat_size=30
# iteration = 2
#
# accuracy = 0.5210
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.005, window_size=200, stat_size=30
# iteration = 3
#
# accuracy = 0.5150
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.005, window_size=200, stat_size=40
# iteration = 1
#
# accuracy = 0.5160
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.005, window_size=200, stat_size=40
# iteration = 2
#
# accuracy = 0.5160
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.005, window_size=200, stat_size=40
# iteration = 3
#
# accuracy = 0.5210
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=100, stat_size=20
# iteration = 1
#
# accuracy = 0.5030
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=100, stat_size=20
# iteration = 2
#
# accuracy = 0.5160
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=100, stat_size=20
# iteration = 3
#
# accuracy = 0.5180
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=100, stat_size=30
# iteration = 1
#
# accuracy = 0.5220
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=100, stat_size=30
# iteration = 2
#
# accuracy = 0.5410
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=100, stat_size=30
# iteration = 3
#
# accuracy = 0.5500
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=100, stat_size=40
# iteration = 1
#
# accuracy = 0.5390
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=100, stat_size=40
# iteration = 2
#
# accuracy = 0.5220
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=100, stat_size=40
# iteration = 3
#
# accuracy = 0.5250
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=200, stat_size=20
# iteration = 1
#
# accuracy = 0.5220
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=200, stat_size=20
# iteration = 2
#
# accuracy = 0.5420
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=200, stat_size=20
# iteration = 3
#
# accuracy = 0.5500
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=200, stat_size=30
# iteration = 1
#
# accuracy = 0.5260
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=200, stat_size=30
# iteration = 2
#
# accuracy = 0.5320
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=200, stat_size=30
# iteration = 3
#
# accuracy = 0.5280
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=200, stat_size=40
# iteration = 1
#
# accuracy = 0.5210
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=200, stat_size=40
# iteration = 2
#
# accuracy = 0.5290
#
# model_name = hoeffdingtreeclassifier
# drift_name = kswin
# drift_args = alpha=0.01, window_size=200, stat_size=40
# iteration = 3
#
# accuracy = 0.5380
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=30.0, alpha=0.99, mode=both
# iteration = 1
#
# accuracy = 0.5020
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=30.0, alpha=0.99, mode=both
# iteration = 2
#
# accuracy = 0.5020
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=30.0, alpha=0.99, mode=both
# iteration = 3
#
# accuracy = 0.5020
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=30.0, alpha=0.99, mode=up
# iteration = 1
#
# accuracy = 0.5020
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=30.0, alpha=0.99, mode=up
# iteration = 2
#
# accuracy = 0.5020
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=30.0, alpha=0.99, mode=up
# iteration = 3
#
# accuracy = 0.5020
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=30.0, alpha=0.99, mode=down
# iteration = 1
#
# accuracy = 0.5020
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=30.0, alpha=0.99, mode=down
# iteration = 2
#
# accuracy = 0.5020
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=30.0, alpha=0.99, mode=down
# iteration = 3
#
# accuracy = 0.5020
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=30.0, alpha=0.9999, mode=both
# iteration = 1
#
# accuracy = 0.5170
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=30.0, alpha=0.9999, mode=both
# iteration = 2
#
# accuracy = 0.5030
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=30.0, alpha=0.9999, mode=both
# iteration = 3
#
# accuracy = 0.5410
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=30.0, alpha=0.9999, mode=up
# iteration = 1
#
# accuracy = 0.5020
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=30.0, alpha=0.9999, mode=up
# iteration = 2
#
# accuracy = 0.5290
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=30.0, alpha=0.9999, mode=up
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=30.0, alpha=0.9999, mode=down
# iteration = 1
#
# accuracy = 0.5020
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=30.0, alpha=0.9999, mode=down
# iteration = 2
#
# accuracy = 0.5090
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=30.0, alpha=0.9999, mode=down
# iteration = 3
#
# accuracy = 0.5020
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=50.0, alpha=0.99, mode=both
# iteration = 1
#
# accuracy = 0.5020
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=50.0, alpha=0.99, mode=both
# iteration = 2
#
# accuracy = 0.5020
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=50.0, alpha=0.99, mode=both
# iteration = 3
#
# accuracy = 0.5030
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=50.0, alpha=0.99, mode=up
# iteration = 1
#
# accuracy = 0.5030
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=50.0, alpha=0.99, mode=up
# iteration = 2
#
# accuracy = 0.5030
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=50.0, alpha=0.99, mode=up
# iteration = 3
#
# accuracy = 0.5030
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=50.0, alpha=0.99, mode=down
# iteration = 1
#
# accuracy = 0.5030
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=50.0, alpha=0.99, mode=down
# iteration = 2
#
# accuracy = 0.5030
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=50.0, alpha=0.99, mode=down
# iteration = 3
#
# accuracy = 0.5030
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=50.0, alpha=0.9999, mode=both
# iteration = 1
#
# accuracy = 0.5060
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=50.0, alpha=0.9999, mode=both
# iteration = 2
#
# accuracy = 0.5030
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=50.0, alpha=0.9999, mode=both
# iteration = 3
#
# accuracy = 0.5090
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=50.0, alpha=0.9999, mode=up
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=50.0, alpha=0.9999, mode=up
# iteration = 2
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=50.0, alpha=0.9999, mode=up
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=50.0, alpha=0.9999, mode=down
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=50.0, alpha=0.9999, mode=down
# iteration = 2
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=50.0, alpha=0.9999, mode=down
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=100.0, alpha=0.99, mode=both
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=100.0, alpha=0.99, mode=both
# iteration = 2
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=100.0, alpha=0.99, mode=both
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=100.0, alpha=0.99, mode=up
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=100.0, alpha=0.99, mode=up
# iteration = 2
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=100.0, alpha=0.99, mode=up
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=100.0, alpha=0.99, mode=down
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=100.0, alpha=0.99, mode=down
# iteration = 2
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=100.0, alpha=0.99, mode=down
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=100.0, alpha=0.9999, mode=both
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=100.0, alpha=0.9999, mode=both
# iteration = 2
#
# accuracy = 0.5090
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=100.0, alpha=0.9999, mode=both
# iteration = 3
#
# accuracy = 0.5100
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=100.0, alpha=0.9999, mode=up
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=100.0, alpha=0.9999, mode=up
# iteration = 2
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=100.0, alpha=0.9999, mode=up
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=100.0, alpha=0.9999, mode=down
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=100.0, alpha=0.9999, mode=down
# iteration = 2
#
# accuracy = 0.5220
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.001, threshold=100.0, alpha=0.9999, mode=down
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=30.0, alpha=0.99, mode=both
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=30.0, alpha=0.99, mode=both
# iteration = 2
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=30.0, alpha=0.99, mode=both
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=30.0, alpha=0.99, mode=up
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=30.0, alpha=0.99, mode=up
# iteration = 2
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=30.0, alpha=0.99, mode=up
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=30.0, alpha=0.99, mode=down
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=30.0, alpha=0.99, mode=down
# iteration = 2
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=30.0, alpha=0.99, mode=down
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=30.0, alpha=0.9999, mode=both
# iteration = 1
#
# accuracy = 0.5440
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=30.0, alpha=0.9999, mode=both
# iteration = 2
#
# accuracy = 0.5390
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=30.0, alpha=0.9999, mode=both
# iteration = 3
#
# accuracy = 0.5030
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=30.0, alpha=0.9999, mode=up
# iteration = 1
#
# accuracy = 0.5270
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=30.0, alpha=0.9999, mode=up
# iteration = 2
#
# accuracy = 0.5210
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=30.0, alpha=0.9999, mode=up
# iteration = 3
#
# accuracy = 0.5210
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=30.0, alpha=0.9999, mode=down
# iteration = 1
#
# accuracy = 0.5280
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=30.0, alpha=0.9999, mode=down
# iteration = 2
#
# accuracy = 0.5100
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=30.0, alpha=0.9999, mode=down
# iteration = 3
#
# accuracy = 0.5150
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=50.0, alpha=0.99, mode=both
# iteration = 1
#
# accuracy = 0.5050
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=50.0, alpha=0.99, mode=both
# iteration = 2
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=50.0, alpha=0.99, mode=both
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=50.0, alpha=0.99, mode=up
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=50.0, alpha=0.99, mode=up
# iteration = 2
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=50.0, alpha=0.99, mode=up
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=50.0, alpha=0.99, mode=down
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=50.0, alpha=0.99, mode=down
# iteration = 2
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=50.0, alpha=0.99, mode=down
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=50.0, alpha=0.9999, mode=both
# iteration = 1
#
# accuracy = 0.5140
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=50.0, alpha=0.9999, mode=both
# iteration = 2
#
# accuracy = 0.5130
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=50.0, alpha=0.9999, mode=both
# iteration = 3
#
# accuracy = 0.5140
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=50.0, alpha=0.9999, mode=up
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=50.0, alpha=0.9999, mode=up
# iteration = 2
#
# accuracy = 0.5100
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=50.0, alpha=0.9999, mode=up
# iteration = 3
#
# accuracy = 0.5070
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=50.0, alpha=0.9999, mode=down
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=50.0, alpha=0.9999, mode=down
# iteration = 2
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=50.0, alpha=0.9999, mode=down
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=100.0, alpha=0.99, mode=both
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=100.0, alpha=0.99, mode=both
# iteration = 2
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=100.0, alpha=0.99, mode=both
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=100.0, alpha=0.99, mode=up
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=100.0, alpha=0.99, mode=up
# iteration = 2
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=100.0, alpha=0.99, mode=up
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=100.0, alpha=0.99, mode=down
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=100.0, alpha=0.99, mode=down
# iteration = 2
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=100.0, alpha=0.99, mode=down
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=100.0, alpha=0.9999, mode=both
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=100.0, alpha=0.9999, mode=both
# iteration = 2
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=100.0, alpha=0.9999, mode=both
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=100.0, alpha=0.9999, mode=up
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=100.0, alpha=0.9999, mode=up
# iteration = 2
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=100.0, alpha=0.9999, mode=up
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=100.0, alpha=0.9999, mode=down
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=100.0, alpha=0.9999, mode=down
# iteration = 2
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.005, threshold=100.0, alpha=0.9999, mode=down
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=30.0, alpha=0.99, mode=both
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=30.0, alpha=0.99, mode=both
# iteration = 2
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=30.0, alpha=0.99, mode=both
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=30.0, alpha=0.99, mode=up
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=30.0, alpha=0.99, mode=up
# iteration = 2
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=30.0, alpha=0.99, mode=up
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=30.0, alpha=0.99, mode=down
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=30.0, alpha=0.99, mode=down
# iteration = 2
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=30.0, alpha=0.99, mode=down
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=30.0, alpha=0.9999, mode=both
# iteration = 1
#
# accuracy = 0.5450
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=30.0, alpha=0.9999, mode=both
# iteration = 2
#
# accuracy = 0.5440
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=30.0, alpha=0.9999, mode=both
# iteration = 3
#
# accuracy = 0.5440
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=30.0, alpha=0.9999, mode=up
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=30.0, alpha=0.9999, mode=up
# iteration = 2
#
# accuracy = 0.5340
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=30.0, alpha=0.9999, mode=up
# iteration = 3
#
# accuracy = 0.5070
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=30.0, alpha=0.9999, mode=down
# iteration = 1
#
# accuracy = 0.5330
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=30.0, alpha=0.9999, mode=down
# iteration = 2
#
# accuracy = 0.5110
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=30.0, alpha=0.9999, mode=down
# iteration = 3
#
# accuracy = 0.5170
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=50.0, alpha=0.99, mode=both
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=50.0, alpha=0.99, mode=both
# iteration = 2
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=50.0, alpha=0.99, mode=both
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=50.0, alpha=0.99, mode=up
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=50.0, alpha=0.99, mode=up
# iteration = 2
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=50.0, alpha=0.99, mode=up
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=50.0, alpha=0.99, mode=down
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=50.0, alpha=0.99, mode=down
# iteration = 2
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=50.0, alpha=0.99, mode=down
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=50.0, alpha=0.9999, mode=both
# iteration = 1
#
# accuracy = 0.5150
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=50.0, alpha=0.9999, mode=both
# iteration = 2
#
# accuracy = 0.5140
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=50.0, alpha=0.9999, mode=both
# iteration = 3
#
# accuracy = 0.5160
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=50.0, alpha=0.9999, mode=up
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=50.0, alpha=0.9999, mode=up
# iteration = 2
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=50.0, alpha=0.9999, mode=up
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=50.0, alpha=0.9999, mode=down
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=50.0, alpha=0.9999, mode=down
# iteration = 2
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=50.0, alpha=0.9999, mode=down
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=100.0, alpha=0.99, mode=both
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=100.0, alpha=0.99, mode=both
# iteration = 2
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=100.0, alpha=0.99, mode=both
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=100.0, alpha=0.99, mode=up
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=100.0, alpha=0.99, mode=up
# iteration = 2
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=100.0, alpha=0.99, mode=up
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=100.0, alpha=0.99, mode=down
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=100.0, alpha=0.99, mode=down
# iteration = 2
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=100.0, alpha=0.99, mode=down
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=100.0, alpha=0.9999, mode=both
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=100.0, alpha=0.9999, mode=both
# iteration = 2
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=100.0, alpha=0.9999, mode=both
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=100.0, alpha=0.9999, mode=up
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=100.0, alpha=0.9999, mode=up
# iteration = 2
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=100.0, alpha=0.9999, mode=up
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=100.0, alpha=0.9999, mode=down
# iteration = 1
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=100.0, alpha=0.9999, mode=down
# iteration = 2
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = pagehinkley
# drift_args = delta=0.01, threshold=100.0, alpha=0.9999, mode=down
# iteration = 3
#
# accuracy = 0.5040
#
# model_name = hoeffdingtreeclassifier
# drift_name = bollingerband
# drift_args = window_size=20, num_std=2, next_drift_delay=20
# iteration = 1
#
# accuracy = 0.5110
#
# model_name = hoeffdingtreeclassifier
# drift_name = bollingerband
# drift_args = window_size=20, num_std=2, next_drift_delay=20
# iteration = 2
#
# accuracy = 0.5320
#
# model_name = hoeffdingtreeclassifier
# drift_name = bollingerband
# drift_args = window_size=20, num_std=2, next_drift_delay=20
# iteration = 3
#
# accuracy = 0.5410
#
# model_name = hoeffdingtreeclassifier
# drift_name = bollingerband
# drift_args = window_size=20, num_std=2, next_drift_delay=50
# iteration = 1
#
# accuracy = 0.5410
#
# model_name = hoeffdingtreeclassifier
# drift_name = bollingerband
# drift_args = window_size=20, num_std=2, next_drift_delay=50
# iteration = 2
#
# accuracy = 0.5410
#
# model_name = hoeffdingtreeclassifier
# drift_name = bollingerband
# drift_args = window_size=20, num_std=2, next_drift_delay=50
# iteration = 3
#
# accuracy = 0.5470
#
# model_name = hoeffdingtreeclassifier
# drift_name = bollingerband
# drift_args = window_size=20, num_std=2, next_drift_delay=100
# iteration = 1
#
# accuracy = 0.5410
#
# model_name = hoeffdingtreeclassifier
# drift_name = bollingerband
# drift_args = window_size=20, num_std=2, next_drift_delay=100
# iteration = 2
#
# accuracy = 0.5470
#
# model_name = hoeffdingtreeclassifier
# drift_name = bollingerband
# drift_args = window_size=20, num_std=2, next_drift_delay=100
# iteration = 3
#
# accuracy = 0.5420
#
# model_name = hoeffdingtreeclassifier
# drift_name = bollingerband
# drift_args = window_size=20, num_std=2.5, next_drift_delay=20
# iteration = 1
#
# accuracy = 0.5310
#
# model_name = hoeffdingtreeclassifier
# drift_name = bollingerband
# drift_args = window_size=20, num_std=2.5, next_drift_delay=20
# iteration = 2
#
# accuracy = 0.5350
#
# model_name = hoeffdingtreeclassifier
# drift_name = bollingerband
# drift_args = window_size=20, num_std=2.5, next_drift_delay=20
# iteration = 3
#
# accuracy = 0.5420
#
# model_name = hoeffdingtreeclassifier
# drift_name = bollingerband
# drift_args = window_size=20, num_std=2.5, next_drift_delay=50
# iteration = 1
#
# accuracy = 0.5460
#
# model_name = hoeffdingtreeclassifier
# drift_name = bollingerband
# drift_args = window_size=20, num_std=2.5, next_drift_delay=50
# iteration = 2
#
# accuracy = 0.5490
#
# model_name = hoeffdingtreeclassifier
# drift_name = bollingerband
# drift_args = window_size=20, num_std=2.5, next_drift_delay=50
# iteration = 3
#
# accuracy = 0.5480
#
# model_name = hoeffdingtreeclassifier
# drift_name = bollingerband
# drift_args = window_size=20, num_std=2.5, next_drift_delay=100
# iteration = 1
#
# accuracy = 0.5400
#
# model_name = hoeffdingtreeclassifier
# drift_name = bollingerband
# drift_args = window_size=20, num_std=2.5, next_drift_delay=100
# iteration = 2
#
# accuracy = 0.5390
#
# model_name = hoeffdingtreeclassifier
# drift_name = bollingerband
# drift_args = window_size=20, num_std=2.5, next_drift_delay=100
# iteration = 3
#
# accuracy = 0.5410
#
# model_name = hoeffdingtreeclassifier
# drift_name = bollingerband
# drift_args = window_size=20, num_std=3.0, next_drift_delay=20
# iteration = 1
#
# accuracy = 0.5240
#
# model_name = hoeffdingtreeclassifier
# drift_name = bollingerband
# ...
# drift_args = window_size=50, num_std=2.5, next_drift_delay=50
# iteration = 3
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=50, num_std=2.5, next_drift_delay=100
# iteration = 1
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=50, num_std=2.5, next_drift_delay=100
# iteration = 2
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=50, num_std=2.5, next_drift_delay=100
# iteration = 3
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=50, num_std=3.0, next_drift_delay=20
# iteration = 1
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=50, num_std=3.0, next_drift_delay=20
# iteration = 2
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=50, num_std=3.0, next_drift_delay=20
# iteration = 3
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=50, num_std=3.0, next_drift_delay=50
# iteration = 1
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=50, num_std=3.0, next_drift_delay=50
# iteration = 2
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=50, num_std=3.0, next_drift_delay=50
# iteration = 3
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=50, num_std=3.0, next_drift_delay=100
# iteration = 1
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=50, num_std=3.0, next_drift_delay=100
# iteration = 2
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=50, num_std=3.0, next_drift_delay=100
# iteration = 3
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=50, num_std=3.5, next_drift_delay=20
# iteration = 1
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=50, num_std=3.5, next_drift_delay=20
# iteration = 2
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=50, num_std=3.5, next_drift_delay=20
# iteration = 3
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=50, num_std=3.5, next_drift_delay=50
# iteration = 1
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=50, num_std=3.5, next_drift_delay=50
# iteration = 2
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=50, num_std=3.5, next_drift_delay=50
# iteration = 3
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=50, num_std=3.5, next_drift_delay=100
# iteration = 1
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=50, num_std=3.5, next_drift_delay=100
# iteration = 2
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=50, num_std=3.5, next_drift_delay=100
# iteration = 3
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=2, next_drift_delay=20
# iteration = 1
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=2, next_drift_delay=20
# iteration = 2
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=2, next_drift_delay=20
# iteration = 3
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=2, next_drift_delay=50
# iteration = 1
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=2, next_drift_delay=50
# iteration = 2
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=2, next_drift_delay=50
# iteration = 3
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=2, next_drift_delay=100
# iteration = 1
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=2, next_drift_delay=100
# iteration = 2
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=2, next_drift_delay=100
# iteration = 3
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=2.5, next_drift_delay=20
# iteration = 1
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=2.5, next_drift_delay=20
# iteration = 2
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=2.5, next_drift_delay=20
# iteration = 3
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=2.5, next_drift_delay=50
# iteration = 1
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=2.5, next_drift_delay=50
# iteration = 2
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=2.5, next_drift_delay=50
# iteration = 3
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=2.5, next_drift_delay=100
# iteration = 1
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=2.5, next_drift_delay=100
# iteration = 2
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=2.5, next_drift_delay=100
# iteration = 3
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=3.0, next_drift_delay=20
# iteration = 1
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=3.0, next_drift_delay=20
# iteration = 2
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=3.0, next_drift_delay=20
# iteration = 3
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=3.0, next_drift_delay=50
# iteration = 1
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=3.0, next_drift_delay=50
# iteration = 2
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=3.0, next_drift_delay=50
# iteration = 3
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=3.0, next_drift_delay=100
# iteration = 1
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=3.0, next_drift_delay=100
# iteration = 2
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=3.0, next_drift_delay=100
# iteration = 3
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=3.5, next_drift_delay=20
# iteration = 1
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=3.5, next_drift_delay=20
# iteration = 2
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=3.5, next_drift_delay=20
# iteration = 3
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=3.5, next_drift_delay=50
# iteration = 1
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=3.5, next_drift_delay=50
# iteration = 2
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=3.5, next_drift_delay=50
# iteration = 3
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=3.5, next_drift_delay=100
# iteration = 1
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=3.5, next_drift_delay=100
# iteration = 2
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=100, num_std=3.5, next_drift_delay=100
# iteration = 3
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=2, next_drift_delay=20
# iteration = 1
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=2, next_drift_delay=20
# iteration = 2
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=2, next_drift_delay=20
# iteration = 3
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=2, next_drift_delay=50
# iteration = 1
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=2, next_drift_delay=50
# iteration = 2
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=2, next_drift_delay=50
# iteration = 3
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=2, next_drift_delay=100
# iteration = 1
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=2, next_drift_delay=100
# iteration = 2
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=2, next_drift_delay=100
# iteration = 3
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=2.5, next_drift_delay=20
# iteration = 1
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=2.5, next_drift_delay=20
# iteration = 2
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=2.5, next_drift_delay=20
# iteration = 3
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=2.5, next_drift_delay=50
# iteration = 1
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=2.5, next_drift_delay=50
# iteration = 2
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=2.5, next_drift_delay=50
# iteration = 3
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=2.5, next_drift_delay=100
# iteration = 1
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=2.5, next_drift_delay=100
# iteration = 2
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=2.5, next_drift_delay=100
# iteration = 3
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=3.0, next_drift_delay=20
# iteration = 1
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=3.0, next_drift_delay=20
# iteration = 2
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=3.0, next_drift_delay=20
# iteration = 3
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=3.0, next_drift_delay=50
# iteration = 1
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=3.0, next_drift_delay=50
# iteration = 2
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=3.0, next_drift_delay=50
# iteration = 3
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=3.0, next_drift_delay=100
# iteration = 1
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=3.0, next_drift_delay=100
# iteration = 2
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=3.0, next_drift_delay=100
# iteration = 3
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=3.5, next_drift_delay=20
# iteration = 1
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=3.5, next_drift_delay=20
# iteration = 2
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=3.5, next_drift_delay=20
# iteration = 3
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=3.5, next_drift_delay=50
# iteration = 1
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=3.5, next_drift_delay=50
# iteration = 2
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=3.5, next_drift_delay=50
# iteration = 3
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=3.5, next_drift_delay=100
# iteration = 1
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=3.5, next_drift_delay=100
# iteration = 2
#
# accuracy = 0.5180
#
# model_name = majorityclass
# drift_name = bollingerband
# drift_args = window_size=200, num_std=3.5, next_drift_delay=100
# iteration = 3
#
# accuracy = 0.5180

# %%
result_df = pd.read_csv('results_df_synth_dataset.csv')
result_df

# %%
sqldf('''
select model_name, drift_name, feature_selector_name, drifts_detected, drift_args, avg(accuracy) as accuracy
from result_df
group by model_name, drift_name, feature_selector_name, learning_threshold, drifts_detected, drift_args
order by accuracy desc
    
''')
# Out:
#                   model_name     drift_name feature_selector_name  \
# 0    hoeffdingtreeclassifier  bollingerband                 tstat
# 1    hoeffdingtreeclassifier  bollingerband                 tstat
# 2    hoeffdingtreeclassifier  bollingerband                 tstat
# 3    hoeffdingtreeclassifier  bollingerband                 tstat
# 4    hoeffdingtreeclassifier  bollingerband                 tstat
# ..                       ...            ...                   ...
# 720  hoeffdingtreeclassifier          adwin                 tstat
# 721  hoeffdingtreeclassifier          adwin                 tstat
# 722  hoeffdingtreeclassifier          adwin                 tstat
# 723  hoeffdingtreeclassifier          adwin                 tstat
# 724  hoeffdingtreeclassifier          adwin                 tstat
#
#      drifts_detected                                         drift_args  \
# 0                 45   window_size=20, num_std=2.5, next_drift_delay=50
# 1                 32  window_size=50, num_std=2.5, next_drift_delay=100
# 2                 57   window_size=50, num_std=2.5, next_drift_delay=20
# 3                 44   window_size=20, num_std=2.5, next_drift_delay=50
# 4                 56   window_size=50, num_std=2.5, next_drift_delay=20
# ..               ...                                                ...
# 720                0  delta=0.002, clock=10, max_buckets=3, grace_pe...
# 721                0  delta=0.002, clock=1, max_buckets=5, grace_per...
# 722                1  delta=0.01, clock=32, max_buckets=3, grace_per...
# 723                0  delta=0.01, clock=32, max_buckets=3, grace_per...
# 724                0  delta=0.002, clock=10, max_buckets=5, grace_pe...
#
#      accuracy
# 0    0.548500
# 1    0.548000
# 2    0.546500
# 3    0.546000
# 4    0.545000
# ..        ...
# 720  0.500667
# 721  0.500333
# 722  0.499000
# 723  0.494500
# 724  0.494000
#
# [725 rows x 6 columns]

# %%
sqldf('''
select model_name, drift_args, avg(accuracy) as accuracy, avg(drifts_detected)
from result_df
where --model_name = 'hoeffdingtreeclassifier' and 
      drift_name = 'kswin'
group by model_name, drift_args
order by accuracy desc
''')
# Out:
#                              model_name  \
# 0   extremelyfastdecisiontreeclassifier
# 1               hoeffdingtreeclassifier
# 2               hoeffdingtreeclassifier
# 3   extremelyfastdecisiontreeclassifier
# 4   extremelyfastdecisiontreeclassifier
# 5   extremelyfastdecisiontreeclassifier
# 6               hoeffdingtreeclassifier
# 7               hoeffdingtreeclassifier
# 8   extremelyfastdecisiontreeclassifier
# 9               hoeffdingtreeclassifier
# 10  extremelyfastdecisiontreeclassifier
# 11              hoeffdingtreeclassifier
# 12  extremelyfastdecisiontreeclassifier
# 13  extremelyfastdecisiontreeclassifier
# 14  extremelyfastdecisiontreeclassifier
# 15              hoeffdingtreeclassifier
# 16  extremelyfastdecisiontreeclassifier
# 17  extremelyfastdecisiontreeclassifier
# 18  extremelyfastdecisiontreeclassifier
# 19              hoeffdingtreeclassifier
# 20              hoeffdingtreeclassifier
# 21                        majorityclass
# 22                        majorityclass
# 23                        majorityclass
# 24                        majorityclass
# 25                        majorityclass
# 26                        majorityclass
# 27                        majorityclass
# 28                        majorityclass
# 29                        majorityclass
# 30                        majorityclass
# 31                        majorityclass
# 32                        majorityclass
# 33              hoeffdingtreeclassifier
# 34              hoeffdingtreeclassifier
# 35              hoeffdingtreeclassifier
# 36                             nochange
# 37                             nochange
# 38                             nochange
# 39                             nochange
# 40                             nochange
# 41                             nochange
# 42                             nochange
# 43                             nochange
# 44                             nochange
# 45                             nochange
# 46                             nochange
# 47                             nochange
#
#                                     drift_args  accuracy  avg(drifts_detected)
# 0    alpha=0.01, window_size=200, stat_size=40  0.537500              5.500000
# 1    alpha=0.01, window_size=100, stat_size=30  0.536000              4.833333
# 2    alpha=0.01, window_size=200, stat_size=20  0.533833              5.000000
# 3    alpha=0.01, window_size=100, stat_size=20  0.533500              3.833333
# 4    alpha=0.01, window_size=100, stat_size=30  0.532500              7.166667
# 5    alpha=0.01, window_size=200, stat_size=30  0.532500              6.833333
# 6    alpha=0.01, window_size=200, stat_size=40  0.531833              5.666667
# 7    alpha=0.01, window_size=200, stat_size=30  0.531500              7.166667
# 8    alpha=0.01, window_size=100, stat_size=40  0.530833              5.000000
# 9   alpha=0.005, window_size=100, stat_size=30  0.530000              3.666667
# 10  alpha=0.005, window_size=100, stat_size=30  0.529667              4.666667
# 11  alpha=0.005, window_size=100, stat_size=40  0.529000              4.333333
# 12  alpha=0.005, window_size=200, stat_size=20  0.528667              6.333333
# 13  alpha=0.005, window_size=200, stat_size=30  0.527667              3.000000
# 14  alpha=0.005, window_size=200, stat_size=40  0.525000              5.000000
# 15  alpha=0.005, window_size=100, stat_size=20  0.524667              3.000000
# 16  alpha=0.005, window_size=100, stat_size=40  0.524333              3.666667
# 17  alpha=0.005, window_size=100, stat_size=20  0.523667              4.666667
# 18   alpha=0.01, window_size=200, stat_size=20  0.523333              3.166667
# 19   alpha=0.01, window_size=100, stat_size=40  0.522000              4.000000
# 20  alpha=0.005, window_size=200, stat_size=20  0.520667              5.333333
# 21  alpha=0.005, window_size=100, stat_size=20  0.518000              4.666667
# 22  alpha=0.005, window_size=100, stat_size=30  0.518000              3.000000
# 23  alpha=0.005, window_size=100, stat_size=40  0.518000              3.000000
# 24  alpha=0.005, window_size=200, stat_size=20  0.518000              3.000000
# 25  alpha=0.005, window_size=200, stat_size=30  0.518000              3.666667
# 26  alpha=0.005, window_size=200, stat_size=40  0.518000              3.666667
# 27   alpha=0.01, window_size=100, stat_size=20  0.518000              3.000000
# 28   alpha=0.01, window_size=100, stat_size=30  0.518000              3.333333
# 29   alpha=0.01, window_size=100, stat_size=40  0.518000              3.500000
# 30   alpha=0.01, window_size=200, stat_size=20  0.518000              2.666667
# 31   alpha=0.01, window_size=200, stat_size=30  0.518000              3.000000
# 32   alpha=0.01, window_size=200, stat_size=40  0.518000              2.500000
# 33  alpha=0.005, window_size=200, stat_size=40  0.517667              5.000000
# 34  alpha=0.005, window_size=200, stat_size=30  0.512667              3.000000
# 35   alpha=0.01, window_size=100, stat_size=20  0.507167              3.666667
# 36  alpha=0.005, window_size=100, stat_size=20  0.505000              0.666667
# 37  alpha=0.005, window_size=100, stat_size=30  0.505000              0.666667
# 38  alpha=0.005, window_size=100, stat_size=40  0.505000              1.333333
# 39  alpha=0.005, window_size=200, stat_size=20  0.505000              1.333333
# 40  alpha=0.005, window_size=200, stat_size=30  0.505000              0.666667
# 41  alpha=0.005, window_size=200, stat_size=40  0.505000              1.000000
# 42   alpha=0.01, window_size=100, stat_size=20  0.505000              1.333333
# 43   alpha=0.01, window_size=100, stat_size=30  0.505000              1.000000
# 44   alpha=0.01, window_size=100, stat_size=40  0.505000              1.166667
# 45   alpha=0.01, window_size=200, stat_size=20  0.505000              1.500000
# 46   alpha=0.01, window_size=200, stat_size=30  0.505000              1.166667
# 47   alpha=0.01, window_size=200, stat_size=40  0.505000              0.666667

# %%
result_df_bis = result_df.copy()
result_df_bis['model_name'] = result_df_bis['model_name'].apply(lambda model_name: 'HT' if model_name=='hoeffdingtreeclassifier' else
                                                                                   'EFDT' if model_name=='extremelyfastdecisiontreeclassifier' else 
                                                                                   model_name)
plt.figure(figsize=(10, 4))
sns.boxplot(x='model_name', y="accuracy", data=result_df_bis)
# plt.title("Accuracy by model")
plt.xticks(rotation=45)
plt.xlabel('model')
plt.tight_layout()
plt.savefig('result_df_images_to_report/synth_data_drift_comparison_model_vs_acc.png')
plt.show()

# %%
plt.figure(figsize=(10, 4))
sns.boxplot(x='drift_name', y="accuracy", data=result_df)
# plt.title("Accuracy by drift detector")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('result_df_images_to_report/synth_data_drift_comparison_drift_detector_vs_acc.png')
plt.show()

# %% [markdown]
# ### INCREASING NUMBER OF DRIFTS TESTS

# %%
dataLoader = SyntheticDataLoader() 

result_rows = []
iterations = 3
feature_selector_name = 'tstat'
learning_threshold = 0
model_name = 'hoeffdingtreeclassifier'
model = tree.HoeffdingTreeClassifier(grace_period=100, max_depth=12)
drift_name = 'bollingerband'
drift_detector = BollingerBandDriftDetector(20, 2.5, 50)

for drifts_num in [3, 5, 7, 9, 11]:
    accuracies = []
    drifts_detected_list = []
    
    for iteration in range(iterations):

        stock_data, regimes = dataLoader.pipeline(n_days=5000, n_drifts=drifts_num, seed=2+iteration)
    
        stock_predictor = StockPredictor(stock_data=stock_data,
                        model_name=model_name,
                        provided_model=model,
                        drift_name=drift_name,
                        feature_selector_name=feature_selector_name,
                        learning_threshold = learning_threshold,
                        provided_detector=drift_detector
                        )
        accuracy, metrics_result = stock_predictor.prediction()
        accuracies.append(accuracy)
        drifts_detected_list.append(stock_predictor.drifts_detected)
    print('accuracy = {:.4f}, drifts num = {}, drifts detected = {}'.format(np.mean(accuracies), drifts_num, round(np.mean(drifts_detected_list), 1)))
# Out:
# accuracy = 0.5397, drifts num = 3, drifts detected = 50.3
# accuracy = 0.5603, drifts num = 5, drifts detected = 49.7
# accuracy = 0.5433, drifts num = 7, drifts detected = 53.7
# accuracy = 0.5390, drifts num = 9, drifts detected = 53.7
# accuracy = 0.5433, drifts num = 11, drifts detected = 51.0

# %%
stock_data, regimes = dataLoader.pipeline(n_days=5000, n_drifts=11, seed=2)

plt.figure(figsize=(12, 4))
for regime in np.unique(regimes):
    subset = [i for i, x in enumerate(regimes) if x == regime]
    plt.plot(subset, stock_data.loc[subset, 'close'], label=f"Regime {regime}")
# plt.title("Synthetic data stream with drifts")
plt.xlabel("Day")
plt.ylabel("Close Price")
plt.legend()
plt.grid(True)
# plt.savefig('result_df_images_to_report/synthetic_data_5_drifts.png')
plt.show()

# %%
dataLoader = SyntheticDataLoader() 

result_rows = []
iterations = 3
feature_selector_name = 'tstat'
learning_threshold = 0
model_name = 'hoeffdingtreeclassifier'
model = tree.HoeffdingTreeClassifier(grace_period=100, max_depth=12)
drift_name = 'no_drift'
drift_detector = drift.DummyDriftDetector(t_0=100000) # no drift

for drifts_num in [3, 5, 7, 9, 11]:
    accuracies = []
    drifts_detected_list = []
    
    for iteration in range(iterations):

        stock_data, regimes = dataLoader.pipeline(n_days=5000, n_drifts=drifts_num, seed=2+iteration)
    
        stock_predictor = StockPredictor(stock_data=stock_data,
                        model_name=model_name,
                        provided_model=model,
                        drift_name=drift_name,
                        feature_selector_name=feature_selector_name,
                        learning_threshold = learning_threshold,
                        provided_detector=drift_detector
                        )
        accuracy, metrics_result = stock_predictor.prediction()
        accuracies.append(accuracy)
        drifts_detected_list.append(stock_predictor.drifts_detected)
    print('accuracy = {:.4f}, drifts num = {}, drifts detected = {}'.format(np.mean(accuracies), drifts_num, round(np.mean(drifts_detected_list))))
# Out:
# accuracy = 0.5277, drifts num = 3, drifts detected = 0
# accuracy = 0.5357, drifts num = 5, drifts detected = 0
# accuracy = 0.5360, drifts num = 7, drifts detected = 1
# accuracy = 0.5337, drifts num = 9, drifts detected = 0
# accuracy = 0.5383, drifts num = 11, drifts detected = 1
